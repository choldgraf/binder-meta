# %%
import pandas as pd
import altair as alt
from pathlib import Path

# %%
data = []
for ifile in Path("../data").glob("*.json"):
    if ifile.name.startswith("2021"):
        data.append(pd.read_json(ifile))
data = pd.concat(data).reset_index(drop=True)

# %% [markdown]
# ## Launches by provider

# %%
provider = data.groupby(['provider', 'date']).agg({'launches': 'sum'}).reset_index()
alt.Chart(provider).mark_line().encode(
    x="date",
    y=alt.Y("launches", scale=alt.Scale(type="log")),
    color="provider"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Launches by origin

# %%
origin = data.groupby(['origin', 'date']).agg({'launches': 'sum'}).reset_index()
alt.Chart(origin).mark_line().encode(
    x="date",
    y=alt.Y("launches", scale=alt.Scale(type="log")),
    color="origin"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Unique repositories

# %%
unique = data.groupby("provider").agg({"spec": "nunique"}).reset_index().rename(columns={"spec": "n_repos"})
alt.Chart(unique, width=400, height=200, title="Unique Repositories").mark_bar().encode(
    x='provider',
    y=alt.Y("n_repos", scale=alt.Scale(type="log")),

)
# Out:
# alt.Chart(...)

# %%
unique
# Out:
#      provider  n_repos
# 0   Dataverse       15
# 1    Figshare       22
# 2        Gist     1208
# 3         Git    40380
# 4      GitHub    44416
# 5      GitLab      899
# 6  Hydroshare       59
# 7      Zenodo       68

# %% [markdown]
# ## Most popular repositories

# %%
launches = data.groupby(['spec']).agg({'launches': 'sum'}).sort_values('launches', ascending=False)
top100 = launches.head(100)

# %%
launches.head(100).sample(10)
# Out:
#                                                     launches
# spec
# lewagon/intro-to-data-science-env/master                3857
# ELC/8fdc0f490b3058872a7014f01416dfb6/master            69236
# spyder-ide/binder-environments/spyder-stable           16613
# scikit-image/scikit-image/main                          4894
# https%3A%2F%2Fgit.tu-berlin.de%2Fdima%2Fisda%2F...      4962
# rationalmatter/juno-demo-notebooks/master               4153
# ipydatabook/ipydatabook.github.io/gh-pages              6731
# Microsoft/QuantumKatas/main                            12262
# tfavory/micro-notebooks/HEAD                            4658
# nlihin/my-binder/HEAD                                   3780

# %% [markdown]
# ## Keyword search

# %%
bio_words = ["dna", "rna", "bio"]

# %%
word_subset = launches[[any(word in ii for word in bio_words) for ii in launches.reset_index()["spec"]]]
print(f"N bio-related repositories: {word_subset.shape[0]}")
word_subset.head(50)
# Out:
# N bio-related repositories: 445
#                                                     launches
# spec
# applied-bioinformatics/built-iab/master                 1586
# rafelyall%2Fbiology-on-the-command-line/master          1039
# AstrobioMike/binder-unix-intro/master                    923
# AstrobioMike/Elinne-RNA-binder/master                    646
# michelbierlaire/biogeme/master                           518
# symbionts/notebooks/master                               347
# AstrobioMike/binder-R-basics/master                      339
# ucla-biostat-257-2020spring/ucla-biostat-257-20...       331
# LaCTAD/stairway-to-biopython/master                      275
# biosignalsplux/biosignalsnotebooks/mybinder_com...       256
# biosignalsnotebooks/biosignalsnotebooks/biosign...       245
# AstrobioMike/binder-dada2-ex-workflow/v3                 232
# jahernando/USC-MMIII/master                              225
# cambiotraining/python-data-science/master                224
# biovcnet/metagenomics-binder-qc/master                   214
# gaelforget/Cbiomes2019Notebooks/master                   139
# biovcnet/functional-annotation-lesson-2-binder/...       139
# harvardinformatics/bioinformatics-coffee-hour/m...       136
# SystemsBiologist/PSCAN/discbio-pub                       127
# hibernator11/notebook-lod-libraries/master               122
# biom262/cmm262-2020/master                               122
# statisticalbiotechnology/cb2030/master                   121
# terna/SLAPP3/master                                      119
# insysbio/likelihoodprofiler-cases/master                 116
# GLAM-Workbench/trove-journals/master                     110
# biof509/spring2020/master                                100
# cBioPortal/2020-cbioportal-r-workshop/master             100
# pablobernabeu/Modality-switch-effects-emerge-ea...        98
# SBRG/ssbio/master                                         95
# hanbioinformatica/studiestart.git/master                  95
# AstrobioMike/binder-bash-intro/master                     86
# hibernator11/notebook-texts-example/master                85
# ArnauMontagud/cobra_cbm_tutorial/master                   84
# cra-international/Intro-to-Python/master                  81
# BernardoAflalo/FGV_Keras_MLP/master                       80
# biovcnet/topic-functional-annotation/master               76
# YeoLab/single-cell-bioinformatics/master                  75
# hibernator11/notebook-iiif-images/master                  68
# AstrobioMike/binder-dada2-ex-workflow/master              62
# bioexcel/biobb_wf_md_setup/master                         61
# yhilpisch/dnanlp/master                                   60
# biovcnet/metagenomics-binder-assembly/master              57
# AstrobioMike/binder-conda-intro/master                    55
# pablobernabeu/Modality-switch-effects-emerge-ea...        55
# pablobernabeu/Modality-exclusivity-norms-747-Du...        52
# nsoranzo/bioblend-tutorial/master                         52
# bioexcel/biobb_wf_pmx_tutorial/master                     51
# ngs-docs/2020-ggg-201b-rnaseq.git/master                  49
# ucla-biostat-200c-2020spring/ucla-biostat-200c-...        48
# ngs-docs/2020-ggg-298-first-day-rnaseq/shannone...        47
